# %%
import pandas as pd
import scipy as sc
import sklearn as sk
import seaborn as sns
import tensorflow as tf
import cv2 
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('Data_Entry_2017.csv')

# %%
df.head()
# Out:
#         Image Index          Finding Labels  Follow-up #  Patient ID  \
# 0  00000001_000.png            Cardiomegaly            0           1
# 1  00000001_001.png  Cardiomegaly|Emphysema            1           1
# 2  00000001_002.png   Cardiomegaly|Effusion            2           1
# 3  00000002_000.png              No Finding            0           2
# 4  00000003_000.png                  Hernia            0           3
#
#    Patient Age Patient Gender View Position  OriginalImage[Width  Height]  \
# 0           58              M            PA                 2682     2749
# 1           58              M            PA                 2894     2729
# 2           58              M            PA                 2500     2048
# 3           81              M            PA                 2500     2048
# 4           81              F            PA                 2582     2991
#
#    OriginalImagePixelSpacing[x     y]  Unnamed: 11
# 0                        0.143  0.143          NaN
# 1                        0.143  0.143          NaN
# 2                        0.168  0.168          NaN
# 3                        0.171  0.171          NaN
# 4                        0.143  0.143          NaN

# %%
df.shape
# Out:
# (112120, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112120 entries, 0 to 112119
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Image Index                  112120 non-null  object
#  1   Finding Labels               112120 non-null  object
#  2   Follow-up #                  112120 non-null  int64
#  3   Patient ID                   112120 non-null  int64
#  4   Patient Age                  112120 non-null  int64
#  5   Patient Gender               112120 non-null  object
#  6   View Position                112120 non-null  object
#  7   OriginalImage[Width          112120 non-null  int64
#  8   Height]                      112120 non-null  int64
#  9   OriginalImagePixelSpacing[x  112120 non-null  float64
#  10  y]                           112120 non-null  float64
#  11  Unnamed: 11                  0 non-null       float64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 10.3+ MB

# %%
pd.set_option('display.float_format',lambda x: '%.3f'%x)
df.describe().transpose()
# Out:
#                                  count      mean      std      min      25%  \
# Follow-up #                 112120.000     8.574   15.406    0.000    0.000
# Patient ID                  112120.000 14346.382 8403.877    1.000 7310.750
# Patient Age                 112120.000    46.901   16.840    1.000   35.000
# OriginalImage[Width         112120.000  2646.079  341.246 1143.000 2500.000
# Height]                     112120.000  2486.439  401.268  966.000 2048.000
# OriginalImagePixelSpacing[x 112120.000     0.156    0.016    0.115    0.143
# y]                          112120.000     0.156    0.016    0.115    0.143
# Unnamed: 11                      0.000       NaN      NaN      NaN      NaN
#
#                                   50%       75%       max
# Follow-up #                     3.000    10.000   183.000
# Patient ID                  13993.000 20673.000 30805.000
# Patient Age                    49.000    59.000   414.000
# OriginalImage[Width          2518.000  2992.000  3827.000
# Height]                      2544.000  2991.000  4715.000
# OriginalImagePixelSpacing[x     0.143     0.168     0.199
# y]                              0.143     0.168     0.199
# Unnamed: 11                       NaN       NaN       NaN

# %%
df.isnull()
# Out:
#         Image Index  Finding Labels  Follow-up #  Patient ID  Patient Age  \
# 0             False           False        False       False        False
# 1             False           False        False       False        False
# 2             False           False        False       False        False
# 3             False           False        False       False        False
# 4             False           False        False       False        False
# ...             ...             ...          ...         ...          ...
# 112115        False           False        False       False        False
# 112116        False           False        False       False        False
# 112117        False           False        False       False        False
# 112118        False           False        False       False        False
# 112119        False           False        False       False        False
#
#         Patient Gender  View Position  OriginalImage[Width  Height]  \
# 0                False          False                False    False
# 1                False          False                False    False
# 2                False          False                False    False
# 3                False          False                False    False
# 4                False          False                False    False
# ...                ...            ...                  ...      ...
# 112115           False          False                False    False
# 112116           False          False                False    False
# 112117           False          False                False    False
# 112118           False          False                False    False
# 112119           False          False                False    False
#
#         OriginalImagePixelSpacing[x     y]  Unnamed: 11
# 0                             False  False         True
# 1                             False  False         True
# 2                             False  False         True
# 3                             False  False         True
# 4                             False  False         True
# ...                             ...    ...          ...
# 112115                        False  False         True
# 112116                        False  False         True
# 112117                        False  False         True
# 112118                        False  False         True
# 112119                        False  False         True
#
# [112120 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# Image Index                         0
# Finding Labels                      0
# Follow-up #                         0
# Patient ID                          0
# Patient Age                         0
# Patient Gender                      0
# View Position                       0
# OriginalImage[Width                 0
# Height]                             0
# OriginalImagePixelSpacing[x         0
# y]                                  0
# Unnamed: 11                    112120
# dtype: int64

# %%
import os
import shutil

# %%
# Specify the source directories and the destination directory
path1 = 'images_001/images'
path2 = 'images_002/images'
path3 = 'images_003/images'
path4 = 'images_004/images'
path5 = 'images_005/images'
path6 = 'images_006/images'
path7 = 'images_007/images'
path8 = 'images_008/images'
path9 = 'images_009/images'
path010 = 'images_010/images'
path011 = 'images_011/images'
path012 = 'images_012/images'
dest_path = 'sample_data'

# Iterate through each source directory and move all files to the destination directory
for path in [path1, path2, path3, path4, path5,path6 , path7,path8,path9,path010,path011,path012]:
    # Iterate through each file in the current source directory
    for file_name in os.listdir(path):
        # Get the full path of the current file
        src_path = os.path.join(path, file_name)
        # Move the current file to the destination directory
        shutil.move(src_path, dest_path)

# %%
import pandas as pd
import numpy as np
import cv2

df_labels = pd.read_csv('Data_Entry_2017.csv')
filename = 'image.jpg'
img = cv2.imread(os.path.join('sample_data', filename))

# %%
# Filter the DataFrame to only include the two labels you want to extract
label1 = 'Cardiomegaly'
label2 = 'Effusion'
df_filtered = df_labels[(df_labels['Finding Labels'] == label1) | (df_labels['Finding Labels'] == label2)]

# Extract the filenames of the images from the filtered DataFrame
image_files = df_filtered['Image Index'].values

# Loop through the image files and save the images with the corresponding label to a new directory
output_dir = 'Finaldataset/'
os.makedirs(output_dir, exist_ok=True)

for filename in image_files:
    label = df_filtered[df_filtered['Image Index'] == filename]['Finding Labels'].values[0]
    output_filename = os.path.join(output_dir, f'{label}_{os.path.basename(filename)}')
    cv2.imwrite(output_filename, img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [27], in <cell line: 13>()
#      14 label = df_filtered[df_filtered['Image Index'] == filename]['Finding Labels'].values[0]
#      15 output_filename = os.path.join(output_dir, f'{label}_{os.path.basename(filename)}')
# ---> 16 cv2.imwrite(output_filename, img)
#
# error: OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:783: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
